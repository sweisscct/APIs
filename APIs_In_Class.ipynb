# %% [markdown]
# ## Application Programming Interface
# Graphical User Interface (GUI)
#
# - Python Libraries!
# - Web APIs : REST APIs
# - Representational State Transfer

# %% [markdown]
# ### REST APIs
# - Protocall https://
# - Web url www.google.com, api.open-meteo.com
# - Endpoint /v1/forecast
# - Query start ?
# - key=value
# - Parameters separated by &
# <br>
# https://api.open-meteo.com/v1/forecast?latitue=52.52&longitude=13.41&hourly=temp_2m
# <br><br>
# https = hypertext transfer protocol (secure)

# %%
import json
import requests

# %%
url = "https://api.open-meteo.com/v1/forecast?latitude=53.2724&longitude=-9.051&current=temperature_2m,rain&hourly=temperature_2m,rain"

# %%
res = requests.get(url)

# %%
res # 200 = Good
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"latitude":53.27,"longitude":-9.05,"generationtime_ms":0.09202957153320312,"utc_offset_seconds":0,"timezone":"GMT","timezone_abbreviation":"GMT","elevation":10.0,"current_units":{"time":"iso8601","interval":"seconds","temperature_2m":"°C","rain":"mm"},"current":{"time":"2023-11-27T12:15","interval":900,"temperature_2m":9.6,"rain":0.00},"hourly_units":{"time":"iso8601","temperature_2m":"°C","rain":"mm"},"hourly":{"time":["2023-11-27T00:00","2023-11-27T01:00","2023-11-27T02:00","2023-11-27T03:00","2023-11-27T04:00","2023-11-27T05:00","2023-11-27T06:00","2023-11-27T07:00","2023-11-27T08:00","2023-11-27T09:00","2023-11-27T10:00","2023-11-27T11:00","2023-11-27T12:00","2023-11-27T13:00","2023-11-27T14:00","2023-11-27T15:00","2023-11-27T16:00","2023-11-27T17:00","2023-11-27T18:00","2023-11-27T19:00","2023-11-27T20:00","2023-11-27T21:00","2023-11-27T22:00","2023-11-27T23:00","2023-11-28T00:00","2023-11-28T01:00","2023-11-28T02:00","2023-11-28T03:00","2023-11-28T04:00","2023-11-28T05:00","2
# ...

# %%
res.text[:10]
# Out:
# '{"latitude'

# %%
data = json.loads(res.text)

# %%
data["latitude"]
# Out:
# 53.27

# %%
type(data)
# Out:
# dict

# %%
data["current"]
# Out:
# {'time': '2023-11-27T12:15',
#  'interval': 900,
#  'temperature_2m': 9.6,
#  'rain': 0.0}

# %%
data["current"]["temperature_2m"]
# Out:
# 9.6

# %%
json_data = json.dumps(data)

# %%
json_data
# Out:
# '{"latitude": 53.27, "longitude": -9.05, "generationtime_ms": 0.09202957153320312, "utc_offset_seconds": 0, "timezone": "GMT", "timezone_abbreviation": "GMT", "elevation": 10.0, "current_units": {"time": "iso8601", "interval": "seconds", "temperature_2m": "\\u00b0C", "rain": "mm"}, "current": {"time": "2023-11-27T12:15", "interval": 900, "temperature_2m": 9.6, "rain": 0.0}, "hourly_units": {"time": "iso8601", "temperature_2m": "\\u00b0C", "rain": "mm"}, "hourly": {"time": ["2023-11-27T00:00", "2023-11-27T01:00", "2023-11-27T02:00", "2023-11-27T03:00", "2023-11-27T04:00", "2023-11-27T05:00", "2023-11-27T06:00", "2023-11-27T07:00", "2023-11-27T08:00", "2023-11-27T09:00", "2023-11-27T10:00", "2023-11-27T11:00", "2023-11-27T12:00", "2023-11-27T13:00", "2023-11-27T14:00", "2023-11-27T15:00", "2023-11-27T16:00", "2023-11-27T17:00", "2023-11-27T18:00", "2023-11-27T19:00", "2023-11-27T20:00", "2023-11-27T21:00", "2023-11-27T22:00", "2023-11-27T23:00", "2023-11-28T00:00", "2023-11-28T01:00", 
# ...

# %%
data['hourly']['time'][0]
# Out:
# '2023-11-27T00:00'

# %%
data['hourly']['temperature_2m'][0]
# Out:
# 9.9

# %%
data['hourly'].keys()
# Out:
# dict_keys(['time', 'temperature_2m', 'rain'])

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Time" : data['hourly']['time'],
    "Tempurature" : data['hourly']['temperature_2m'],
    "Rain" : data['hourly']['rain']
})

# %%
df.head()
# Out:
#                Time  Tempurature  Rain
# 0  2023-11-27T00:00          9.9   0.0
# 1  2023-11-27T01:00          9.8   0.0
# 2  2023-11-27T02:00          9.7   0.0
# 3  2023-11-27T03:00          9.7   0.0
# 4  2023-11-27T04:00          9.6   0.0

# %%
df2 = pd.DataFrame(data['hourly'])

# %%
df2.head()
# Out:
#                time  temperature_2m  rain
# 0  2023-11-27T00:00             9.9   0.0
# 1  2023-11-27T01:00             9.8   0.0
# 2  2023-11-27T02:00             9.7   0.0
# 3  2023-11-27T03:00             9.7   0.0
# 4  2023-11-27T04:00             9.6   0.0

# %%
df3 = pd.DataFrame(data)

# %%
df3.shape
# Out:
# (4, 11)

# %%
df.shape
# Out:
# (168, 3)

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'current_units', 'current', 'hourly_units', 'hourly'])

# %%
data["current"].keys()
# Out:
# dict_keys(['time', 'interval', 'temperature_2m', 'rain'])

# %%
data["current"]["temperature_2m"]
# Out:
# 9.6
